# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ichristov/intermediate-fluid-mechanics/blob/main/extras/rectangular_duct.ipynb)

# %% [markdown]
# # LEARNING OBJECTIVE
#
# After exploring this notebook, you will be able to find (by separation of variables and Fourier series), plot, and interpret the unidirectional flow solution for steady Poiseuille flow in a 3D duct of rectangular cross-section.

# %% [markdown]
# # PRELIMINARIES
#
# [run the next cell to setup Python environment customizations and load packages]

# %%
# interactive plots setup
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# sympy setup
import sympy as sp
sp.init_printing()
from sympy.vector import *

# plotting customizations
from matplotlib import colormaps, animation, rc
from matplotlib import pyplot as plt
size=16
params = {'legend.fontsize': 'large',
#          'figure.figsize': (20,8),
          'axes.labelsize': size,
          'axes.titlesize': size,
          'xtick.labelsize': size*0.875,
          'ytick.labelsize': size*0.875,
          'axes.titlepad': 25}
plt.rcParams.update(params)
# %matplotlib inline

# numerics
import numpy as np
from scipy.optimize import fsolve

# for Colab only: to save plots as files and download them
#from google.colab import files

# %% [markdown]
# ## Credit
#
# Initial version written by [Ivan C. Christov](http://christov.tmnt-lab.org), Purdue University.

# %% [markdown]
# # FLOW IN A 3D DUCT WITH RECTANGULAR CROSS SECTION

# %% [markdown]
# ## Problem statement

# %% [markdown]
# In this notebook, I present an alternative (to Panton's section 11.2) analysis of the unidirectional flow in a rectangular tube. My approach actually follows _Theoretical Microfluidics_ [(Bruus, 2008)](http://homes.nano.aau.dk/lg/Lab-on-Chip2008_files/HenrikBruus_Microfluidics%20lectures.pdf) (section 2.4.5). The first solution to this problem appears to have been by [Boussinesq (1868)](https://www.numdam.org/item/JMPA_1868_2_13__377_0.pdf).
#
# Let $\underline{v}=\big(v_x(y,z,t),0,0\big)$ be our unidirectional flow profile. The flow domain is the box defined by $\{(x,y,z) \;|\; 0\le x \le L,\; -w/2 \le y \le w/2,\; 0\le z \le h\}$ (see diagram below; the origin is where the red axes meet).

# %% [markdown]
# ![A rectangular duct drawn in oblique projection, closed on all four sides and open at both ends, with the near opening facing the viewer. Its width w is dimensioned across the bottom of the near opening, its height h up that opening, and its length L along the receding lower edge. The top and near side wall are semi-transparent, so the far corner reads through them as a continuous edge and the inner floor and side wall are visible through the opening. Red axes meet at the midpoint of the near bottom edge: x runs into the duct along its length, y across the width, z upward.](data:image/png;base64,...)

# %% [markdown]
# ## Governing equations

# %% [markdown]
# First, let us use [SymPy](https://docs.sympy.org/latest/tutorial/index.html) to verify that $\underline{v}\cdot\nabla\underline{v}=\underline{0}$ for this flow.

# %%
x, y, z = sp.symbols('x y z')
v_x = sp.Function('v_x')(y, z)

velfield = [v_x, 0, 0]

# this is one convenient way to calculate the gradient of a vector,
# sort of as a "Jacobian"
gradv = sp.derive_by_array(velfield, [x, y, z]).tomatrix()

print('grad v is')
gradv
# Out:
# grad v is
# ⎡     0        0  0⎤
# ⎢                  ⎥
# ⎢∂                 ⎥
# ⎢──(vₓ(y, z))  0  0⎥
# ⎢∂y                ⎥
# ⎢                  ⎥
# ⎢∂                 ⎥
# ⎢──(vₓ(y, z))  0  0⎥
# ⎣∂z                ⎦

# %%
# check v*grad(v) = 0, realizing it is grad(v)^t * v
# when coded up as a right vector-matrix multiplication
print('v * grad v is')
gradv.transpose()*sp.Matrix(velfield)
# Out:
# v * grad v is
# ⎡0⎤
# ⎢ ⎥
# ⎢0⎥
# ⎢ ⎥
# ⎣0⎦

# %% [markdown]
# **Detour**: recall that $\nabla^2\underline{v}=\nabla\cdot\nabla\underline{v}$ by definition. Also (index notation exercise), the divergence of a tensor can be reformulated as $\nabla\cdot\underline{\underline{T}}=\partial_jT_{ji} = \partial_k T_{ji} \delta_{kj} = \nabla\underline{\underline{T}}:\underline{\underline{\delta}}$, where $\delta$ is the Kronecker symbol/identity tensor. So, $\nabla^2\underline{v} = (\nabla\nabla\underline{v}):\underline{\underline{\delta}}$. Looks terrible, no? 🙂 But it's true. In index notation, it is simply the "double contraction," which yields $\partial_j\partial_jv_i$ (the Laplacian) after using the properties of the Kronecker symbol. This identity gives a way to compute the Laplacian as "div grad" in SymPy.

# %%
# gradient of the gradient of the velocity
gradgradv = sp.derive_by_array(gradv, (x, y, z))
# sp.pprint(gradgradv)

# double contraction with the identity across 1st (0) and 2nd (1) indices
laplv = sp.Matrix(sp.tensorcontraction(gradgradv, (0, 1)))
laplv
# Out:
# ⎡ 2               2           ⎤
# ⎢∂               ∂            ⎥
# ⎢───(vₓ(y, z)) + ───(vₓ(y, z))⎥
# ⎢  2               2          ⎥
# ⎢∂y              ∂z           ⎥
# ⎢                             ⎥
# ⎢              0              ⎥
# ⎢                             ⎥
# ⎣              0              ⎦

# %% [markdown]
# Thus, for this flow, the incompressible Navier&ndash;Stokes (iNS) equations reduce to
# \begin{align*}
#     \rho\frac{\partial v_x}{\partial t} &= -\frac{\partial p}{\partial x} + \mu\left( \frac{\partial^2 v_x}{\partial y^2} + \frac{\partial^2 v_x}{\partial z^2} \right),\\
#     0 &= -\frac{\partial p}{\partial y},\\
#     0 &= -\frac{\partial p}{\partial z}.
# \end{align*}
# Thus, $p=p(x)$ only, and we can show that $-\partial p/\partial x = -dp/dx = \Delta p/L$. $\Delta p$ is the pressure drop in the axial direction, which is assumed given/known. The first equation is the sought-after  partial differential equation (PDE) for $v_x(y,z,t)$.

# %% [markdown]
# ### Initial and boundary conditions

# %% [markdown]
# Next, we need to specify appropriate boundary conditions (BCs) and initial conditions (ICs). Observe that, by counting the number of spatial derivatives, 2 boundary conditions would be needed in each of $y$ and $z$ because we have two partial derivatives with respect to each in the PDE.
#
# We realize that the fluid cannot slip at the top, bottom, left and right wall of the duct. Those walls are stationary, hence the fluid velocity there must vanish:
# $$
#     v_x(y=-w/2,z,t) = v_x(y=+w/2,z,t) = 0,\qquad v_x(y,z=0,t) = v_x(y,z=h,t) = 0.
# $$
# The initial condition is any function $v_{x,0}$ of $y$ and $z$ that we choose to specify:
# $$
#     v_x(y,z,t=0) = v_{x,0}(y,z).
# $$

# %% [markdown]
# ## Solution by separation of variables

# %% [markdown]
# Now, let us assume that the flow is steady, i.e., $v_x=v_x(y,z)$ is independent of $t$. Additionally, since $v_x \ne v_x(x)$, the longitudinal pressure gradient $-\partial p/\partial x = \Delta p/L$ is a given/known constant. Hence, the _boundary value problem_ (BVP) to be solved is
# \begin{align*}
#     -\frac{\Delta p}{\mu L} &=  \frac{\partial^2 v_x}{\partial y^2} + \frac{\partial^2 v_x}{\partial z^2}, &\quad\text{(PDE)}\\
#     v_x(-w/2,z) &= v_x(+w/2,z) = 0, &\quad\text{(BC1)}\\
#     v_x(y,0) &= v_x(y,h) = 0, &\quad\text{(BC2)}
# \end{align*}
#
# Now, we proceed by _separation of variables_. Unfortunately (PDE) is _inhomogeneous_, so you might immediately see that letting $v_x(y,z)=f(y)g(z)$ fails to separate the variables. Now what? We could try to transform (PDE) to a homogeneous problem (Panton's approach) or we could try a creative guess.

# %% [markdown]
# ### A clever idea

# %% [markdown]
# We observe that if the $z$-dependence were ignored, the problem would be that of Poiseuille flow in a slot. So why not try to "guess" some $g(z)$ and try to solve for the "new" $y$ dependence of Poiseuille flow in the duct? Somehow, this makes physical sense.
#
# If $g(z) = \sin\left(n\pi\frac{z}{h}\right)$, then certainly (BC2) is satisfied for any integer $n=1,2,3,...$ since $\sin(0) = \sin(n\pi) = 0$. So, let us guess:
# $$
#     v_x(y,z) = \sum_{n=1}^\infty f_n(y) \sin\left(n\pi\frac{z}{h}\right).
# $$
# This guess (or, in mathematical language an [_ansatz_](https://en.wikipedia.org/wiki/Ansatz)) is in the form of a separation of variables solution. Substituting it into (PDE) and the remaining (BC1), we have:
# \begin{align*}
#     &-\frac{\Delta p}{\mu L} =  \sum_{n=1}^\infty f_n''(y) \sin\left(n\pi\frac{z}{h}\right) + \sum_{n=1}^\infty f_n(y) \sin\left(n\pi\frac{z}{h}\right) \left[-\frac{n^2\pi^2}{h^2}\right] , &\quad\text{(PDE)}\\
#     &\sum_{n=1}^\infty f_n(-w/2) \sin\left(n\pi\frac{z}{h}\right) = 0,\quad \sum_{n=1}^\infty f_n(+w/2) \sin\left(n\pi\frac{z}{h}\right) = 0. &\quad\text{(BC1)}
# \end{align*}

# %% [markdown]
# ### What is the Fourier sine series of 1?

# %% [markdown]
# The transformed version of (PDE) faces one challenge: the left-hand side is not a Fourier series in $\sin\left(n\pi\frac{z}{h}\right)$.
#
# Noting that $-\Delta p/(\mu L)$ is just a constant, let us compute the Fourier sine series of $1$ and multiply it by $-\Delta p/(\mu L)$. To do so, we recall a theorem.
#
# **Theorem**: The _full_ Fourier series of the odd extension of a function on $z^*\in[-1,1]$ is precisely the Fourier _sine_ series of the function on $z^*\in[0,1]$.
#
# The odd extension of "1" is simply
# $$
#     1_\mathrm{odd} = \begin{cases} -1 , &\quad -1\le z^* < 0,\\ +1, &\quad 0\le z^*\le +1. \end{cases}
# $$
# So:

# %%
# zstar
zs = sp.symbols('zs')
# use the piecewise function definition from SymPy to define the odd extension:
s = sp.fourier_series(sp.Piecewise(
    (1, zs > 0), (-1, zs < 0), (0, True)), (zs, -1, 1))
s
# Out:
# 4⋅sin(π⋅zs)   4⋅sin(3⋅π⋅zs)   4⋅sin(5⋅π⋅zs)
# ─────────── + ───────────── + ───────────── + …
#      π             3⋅π             5⋅π

# %% [markdown]
# So the pattern is clear:
# $$
#     1 = \frac{4}{\pi} \sum_{n \;\text{odd}} \frac{1}{n}\sin\left(n\pi\frac{z}{h}\right),\qquad 0<z<h.
# $$
# Hence:
# $$
#     -\frac{\Delta p}{\mu L}=-\frac{\Delta p}{\mu L}\frac{4}{\pi} \sum_{n \;\text{odd}} \frac{1}{n}\sin\left(n\pi\frac{z}{h}\right).
# $$
#
# Substituting into the governing equations:
# \begin{align*}
#     &-\frac{\Delta p}{\mu L}\frac{4}{\pi} \sum_{n \;\text{odd}} \frac{1}{n}\sin\left(n\pi\frac{z}{h}\right) =  \sum_{n=1}^\infty \left\{ f_n''(y) - \left[-\frac{n^2\pi^2}{h^2}\right] f_n(y) \right\} \sin\left(n\pi\frac{z}{h}\right), &\quad\text{(PDE)}\\
#     &\sum_{n=1}^\infty f_n(-w/2) \sin\left(n\pi\frac{z}{h}\right) = 0,\quad \sum_{n=1}^\infty f_n(+w/2) \sin\left(n\pi\frac{z}{h}\right) = 0. &\quad\text{(BC1)}
# \end{align*}
#
# Now, recall the following **theorem**: if two Fourier sin series converge, then they are equal if and only if all their coefficients agree.
#
# So, we match even/odd terms multiplying the same sines in each of the series on the left- and right-hand sides of (PDE):
# \begin{align*}
#     0 =  f_n''(y) +  f_n(y) \left[-\frac{n^2\pi^2}{h^2}\right], &\qquad n \text{ even},\\
#     -\frac{4\Delta p}{\pi\mu L} \frac{1}{n} =  f_n''(y)  +  f_n(y)  \left[-\frac{n^2\pi^2}{h^2}\right], &\qquad n \text{ odd},
# \end{align*}
# and (BC1):
# $$
#     f_n(-w/2) = f_n(+w/2) = 0,\qquad\text{all } n.
# $$

# %% [markdown]
# ### Solving for $f_n(y)$

# %% [markdown]
# Now it's a matter of solving 2 second-order ODEs with the given BCs. You can verify for yourself that $f_n(y) = 0$ for $n$ even because it is a _homogeneous_ ODE with _homogeneous_ BC, which always yields the trivial solution $f_n(y) = 0$.
#
# Now, we must consider the case of $n$ odd carefully. A particular solution can be guessed by inspection; it must be a constant. To see that, consider
# $$
#     f_{n,\text{particular}}(y) = K \quad\Rightarrow\quad -\frac{4\Delta p}{\pi\mu L} \frac{1}{n} = 0  +  K  \left[-\frac{n^2\pi^2}{h^2}\right] \quad\Rightarrow\quad K = \frac{4h^2\Delta p}{\pi^3\mu L n^3}.
# $$
# Now, we must find the homogeneous solution. The characteristic polynomial of the ODE is
# $$
#     r^2 - \frac{n^2\pi^2}{h^2} = 0 \qquad\Rightarrow\qquad  r = \pm \frac{n\pi}{h},
# $$
# hence
# $$
#     f_{n,\text{homogeneous}}(y) = c_1 e^{\frac{n\pi}{h} y} + c_2 e^{-\frac{n\pi}{h} y}.
# $$
# Finally, we find that,
# $$
#     f_n(y) = \frac{4h^2\Delta p}{\pi^3\mu L n^3} + c_1 e^{\frac{n\pi}{h} y} + c_2 e^{-\frac{n\pi}{h} y}, \qquad n \text{ odd}.
# $$
#
# Now, we must apply the BCs:
# \begin{align*}
#     f_n(-w/2) &= \frac{4h^2\Delta p}{\pi^3\mu L n^3} + c_1 e^{-\frac{n\pi w}{2h}} + c_2 e^{\frac{n\pi w}{2h}} = 0,\\
#     f_n(w/2) &= \frac{4h^2\Delta p}{\pi^3\mu L n^3} + c_1 e^{\frac{n\pi w}{2h}} + c_2 e^{-\frac{n\pi w}{2h}} = 0.
# \end{align*}
# These are two algebraic equations in two unknowns ($c_1$ and $c_2$). Subtracting the 2nd from the first and performing some manipulations:
# $$
#     -2 c_1\left( \frac{e^{\frac{n\pi w}{2h}} - e^{-\frac{n\pi w}{2h}}}{2} \right) + 2 c_2 \left( \frac{e^{\frac{n\pi w}{2h}} - e^{-\frac{n\pi w}{2h}}}{2} \right) = 0.
# $$
# Introducing hyperbolic trigonometric functions:
# $$
#     -2 c_1\sinh\left(\frac{n\pi w}{2h}\right) + 2 c_2 \sinh\left(\frac{n\pi w}{2h}\right) = 0 \qquad\Rightarrow\qquad c_2 = c_1.
# $$
# Returning back to the BCs to evaluate $c_1$:
# $$
#     c_1 = -\frac{2h^2\Delta p}{\pi^3\mu L n^3 \cosh\left(\frac{n\pi w}{2h}\right)}.
# $$

# %% [markdown]
# Finally,
# $$
#     f_n(y) = \begin{cases} \displaystyle \frac{4h^2\Delta p}{\pi^3\mu L n^3}\left\{1 -\frac{ \cosh\left(\frac{n\pi}{h} y\right)}{\cosh\left(\frac{n\pi}{h} \frac{w}{2}\right)}\right\},&\quad n \text{ odd},\\
#     0,&\quad n\text{ even}. \end{cases}
# $$
#
# We can check our ODE solution with SymPy as well:

# %%
dp, mu, L, y, h, w = sp.symbols('dp mu L y h w', positive=True)

# we can define n to be specifically a SymPy integer,
# though it's not important for this calculation.
# I ensured it is positive, to rule n=0, which is not of interest.
n = sp.symbols('n', integer=True, positive=True)

# to ensure f is "callable" with different arguments,
# we don't explicitly write "(y)" at end
f = sp.Function('f')

ode_odd = sp.Eq(f(y).diff(y, y) - n**2*sp.pi**2 /
                h**2*f(y), -4*dp/(n*mu*sp.pi*L))
bcs = {f(-w/2): 0, f(w/2): 0}
# note that odesol is an *equation* f(y) = rhs, and the rhs is the solution
odesol_odd = sp.dsolve(ode_odd, f(y), ics=bcs)

ode_even = sp.Eq(f(y).diff(y, y) - n**2*sp.pi**2/h**2*f(y), 0)
odesol_even = sp.dsolve(ode_even, f(y), ics=bcs)

# %%
print('for n odd:')
odesol_odd
# Out:
# for n odd:
#        ⎛                     2⋅π⋅n⋅w                                  π⋅n⋅w    ↪
#        ⎜                     ───────                                  ─────    ↪
#        ⎜                  2     h                                  2    h      ↪
#        ⎜            4⋅dp⋅h ⋅ℯ                                4⋅dp⋅h ⋅ℯ         ↪
# f(y) = ⎜- ───────────────────────────────────── + ──────────────────────────── ↪
#        ⎜             5⋅π⋅n⋅w              π⋅n⋅w              5⋅π⋅n⋅w           ↪
#        ⎜             ───────              ─────              ───────           ↪
#        ⎜   3      3    2⋅h      3      3   2⋅h     3      3    2⋅h      3      ↪
#        ⎝  π ⋅L⋅μ⋅n ⋅ℯ        - π ⋅L⋅μ⋅n ⋅ℯ        π ⋅L⋅μ⋅n ⋅ℯ        - π ⋅L⋅μ⋅ ↪
#
# ↪          ⎞          ⎛                                 9⋅π⋅n⋅w                ↪
# ↪          ⎟  π⋅n⋅y   ⎜                                 ───────                ↪
# ...

# %%
# the latter is very ugly and I couldn't get it to simplify,
# but we can check our solution solves the ODE too
my_odesol_odd = 4*h**2*dp/(sp.pi**3*mu*L*n**3) * \
    (1 - sp.cosh(n*sp.pi*y/h)/sp.cosh(n*sp.pi*w/(2*h)))
print('does it satisfy the ODE?')
print(sp.checkodesol(ode_odd, my_odesol_odd)[0])

# checkodesol tests only the ODE, not the BCs, so check those separately:
# any cosh denominator that is constant in y satisfies the ODE, and only
# the right one also vanishes at the walls
print('does it satisfy the 2 BCs?')
print(sp.simplify(my_odesol_odd.subs(y, -w/2)) == 0, ",",
      sp.simplify(my_odesol_odd.subs(y, w/2)) == 0)
# Out:
# does it satisfy the ODE?
# True
# does it satisfy the 2 BCs?
# True , True

# %%
print('for n even:')
odesol_even
# Out:
# for n even:
# f(y) = 0

# %% [markdown]
# ### Final result for the velocity profile $v_x(y,z)$

# %% [markdown]
# Putting it all together:
# $$
#     v_x(y,z) = \frac{4h^2\Delta p}{\pi^3\mu L}\sum_{n,\text{ odd}}^\infty \frac{1}{n^3} \left\{1 -\frac{ \cosh\left(\frac{n\pi}{h} y\right)}{\cosh\left(\frac{n\pi}{h}\frac{w}{2}\right)}\right\} \sin\left(n\pi\frac{z}{h}\right).
# $$
#
# We can also write down a dimensionless version. Let $\mathcal{V}_\mathrm{char} = \frac{h^2 \Delta p}{2\mu L}$ (should look familiar from Poiseuille flow in a slot!), $v_x^*=v_x/\mathcal{V}_\mathrm{char}$, $z^*=z/h$, $y^*=y/w$. Then,
# $$
#     v_x^*(y^*,z^*) = \frac{8}{\pi^3}\sum_{n,\text{ odd}}^\infty \frac{1}{n^3} \left\{ 1 -\frac{\cosh\left(n\pi \delta y^*\right)}{\cosh\left(n\pi\delta/2\right)} \right\} \sin\left(n\pi z^*\right),
# $$
# where $\delta = w/h$ is the _aspect ratio_ of the rectangular cross-section (perpendicular to the flow) of the duct, $\{ (y^*,z^*) \;|\; -1/2 \le y^* \le 1/2,\; 0\le z^* \le 1 \}$.

# %% [markdown]
# # ANALYSIS AND DISCUSSION

# %% [markdown]
# ## Plots

# %% [markdown]
# First, we make some plots of the dimensionless solution. Note that we have scaled/normalized the horizontal and vertical axes, so making the duct wider doesn't show up in the plot's aspect ratio, rather the width of the duct manifests itself through the dependence of $v_x^*$ on $\delta$.

# %%
def vx_eval(delta, y, z):
    # number of terms in series to add ... careful though, because
    # if you pick too many, they become so small that you get
    # numerical underflow errors for large delta
    nmax = 50
    vx = 0
    for n in range(1, nmax, 2):
        vx = vx + (8/np.pi**3)*(1/n**3) \
            * (1 - np.cosh(n*np.pi*delta*y)/np.cosh(n*np.pi*delta/2)) \
            * np.sin(n*np.pi*z)

    return vx

# %%
def contour_plot_func(δ, save=False):
    y, z = np.meshgrid(np.linspace(-1/2, 1/2, num=101),
                       np.linspace(0, 1, num=101))

    vx = vx_eval(δ, y, z)

    fig, ax = plt.subplots(tight_layout=True)
    # ax = plt.axes(projection='3d')
    ax.set_xlabel('$y^*$')
    ax.set_ylabel('$z^*$')

    cs = ax.contourf(y, z, vx, 10, cmap='Blues')
    # cs = ax.plot_surface(y, vx, z, linewidth=0, antialiased=False)

    # make a colorbar for the ContourSet returned by contourf
    cbar = plt.colorbar(cs)

    cbar.ax.set_ylabel('$v_x^*(y^*,z^*)$')

    # skew the axis aspect ratio to emphasize the horizontal direction
    # as "long" because we'll consider δ >= 1
    ax.set_aspect(1/1.3)

    # ax.grid(alpha=0.5, linestyle='dotted')

    if save:
        fig.savefig(save) # bbox_inches='tight'

    plt.show()

# %% [markdown]
# First, a static plot.

# %%
contour_plot_func(1)

# %% [markdown]
# Then, an [`interact`](https://ipywidgets.readthedocs.io/en/latest/examples/Using%20Interact.html) widget will let us vary $\delta$.

# %%
interact(contour_plot_func, 
         δ=widgets.FloatSlider(value=1, min=0.5, max=8.0, step=0.5, description='Aspect rat. δ'),
         save=fixed(False));

# %% [markdown]
# We can also make plots of the profile in the vertical ($y^*=0$) and horizontal ($z^*=1/2$) centerplanes.

# %%
def plane_plot_func(δ, save=False):
    # grab axes of figure with 2 subplots horizontally arranged
    fig, (ax0, ax1) = plt.subplots(1, 2)

    # evaluate z* = 1/2 cross-sectional profile
    y = np.linspace(-1/2, 1/2, num=101)
    vx = vx_eval(δ, y, 1/2*np.ones(np.shape(y)))

    # left subplot
    ax0.set_xlabel('$y^*$')
    ax0.set_ylabel('$v_x^*(y^*,1/2)$')
    ax0.plot(y, vx, color='darkblue', linewidth=3)
    # add velocity arrows, skipping every 4th data point for clarity
    ax0.quiver(y[::4], 0*y[::4], 0*vx[::4], vx[::4],
               scale=1., scale_units='xy', color='blue', width=0.0125, zorder=2)
    ax0.set(xlim=(-0.51, 0.51), ylim=(0, 0.255))
    # ax0.set_aspect(1)

    ax0.grid(alpha=0.5, linestyle='dotted')

    # evaluate y* = 0 cross-sectional profile
    z = np.linspace(0, 1, num=101)
    vx = vx_eval(δ, np.zeros(np.shape(z)), z)

    # right subplot
    ax1.set_xlabel('$v_x^*(0,z^*)$')
    ax1.set_ylabel('$z^*$')
    ax1.plot(vx, z, color='darkred', linewidth=3)
    # add velocity arrows, skipping every 4th data point for clarity
    ax1.quiver(0*z[::4], z[::4], vx[::4], 0*vx[::4],
               scale=1., scale_units='xy', color='red', width=0.0125, zorder=2)
    ax1.yaxis.tick_right()
    ax1.yaxis.set_label_position("right")
    ax1.set(xlim=(0, 0.255), ylim=(0, 1))

    ax1.grid(alpha=0.5, linestyle='dotted')

    if save:
        fig.savefig(save) # bbox_inches='tight'

    plt.show()

# %% [markdown]
# First, a static plot.

# %%
plane_plot_func(1)

# %% [markdown]
# Then, an [`interact`](https://ipywidgets.readthedocs.io/en/latest/examples/Using%20Interact.html) widget will let us vary $\delta$.

# %%
interact(plane_plot_func, 
         δ=widgets.FloatSlider(value=1, min=0.2, max=9.0, step=0.4, description='Aspect rat. δ'),
         save=fixed(False));

# %% [markdown]
# ## Width and sidewalls effect

# %% [markdown]
# **Hypothesis**: The flow along the centerline $y^*=0$ should look like flow in a slot if $w\gg h$ (equivalently, $\delta \gg 1$). But how large should $\delta$ be to have them agree, which means the effect of the lateral sidewalls of the channel at $y=\pm w/2$ is negligible at the centerline?
#
# First, let us evaluate the dimensionless solution at $y^*=0$:
# $$
#     v_x^*(0,z^*) = \frac{8}{\pi^3} \sum_{n,\text{ odd}}^\infty \frac{1}{n^3} \left\{1 - \frac{1}{\cosh\left(n\pi\delta/2\right)}\right\} \sin\left(n\pi z^*\right).
# $$
# Second, we recall that the corresponding dimensionless solution (using the same $\mathcal{V}_\mathrm{char}$ as above) for Poiseuille flow in a slot (with $z$ as the transverse coordinate) is:
# $$
#     v_{x,P}^*(z^*) = z^* - \left(z^*\right)^2 .
# $$
#
# First, let's compare the two visually.

# %%
def plane_plot_func_compare(δ, save=False):
    # grab axes of figure with 2 subplots horizontally arranged
    fig, ax = plt.subplots(tight_layout=True)

    # evaluate y* = 0 cross-sectional profile
    z = np.linspace(0, 1, num=101)
    vx = vx_eval(δ, np.zeros(np.shape(z)), z)

    # evaluate the Poiseuille profile
    vx_p = z - z**2

    ax.set_xlabel('$v_x^*$')
    ax.set_ylabel('$z^*$')
    ax.plot(vx, z, color='darkred', linewidth=3, label='$v_x^*(0,z^*)$')
    ax.plot(vx_p, z, color='black', linewidth=3,
            linestyle='dashed', label='$v_{x,P}^*(z^*)$')
    # add velocity arrows, skipping every 4th data point for clarity
    ax.quiver(0*z[::4], z[::4], vx[::4], 0*vx[::4],
              scale=1., scale_units='xy', color='red', zorder=2)
    ax.yaxis.tick_right()
    ax.yaxis.set_label_position("right")
    ax.set(xlim=(0, 0.255), ylim=(0, 1))

    ax.legend()

    ax.grid(alpha=0.5, linestyle='dotted')

    if save:
        fig.savefig(save) # bbox_inches='tight'

    plt.show()

# %% [markdown]
# First, a static plot.

# %%
plane_plot_func_compare(1)

# %% [markdown]
# Then, an [`interact`](https://ipywidgets.readthedocs.io/en/latest/examples/Using%20Interact.html) widget will let us vary $\delta$.

# %%
interact(plane_plot_func_compare, 
         δ=widgets.FloatSlider(value=1, min=0.1, max=4.0, step=0.1, description='Aspect rat. δ'),
         save=fixed(False));

# %% [markdown]
# Next, we seek a value of $\delta = w/h$ such that $\max_{z^*} |v_x^*(0,z^*)-v_{x,P}^*(z^*)| \simeq 0.01$. This criterion is not unique but is a robust way to compare the profiles, via their maximal velocities. (You could've required that the averages are within 1%, or any number of other criteria.)
#
# Both velocity profiles, $v_x^*(0,z^*)$ and $v_{x,P}^*(z^*)$, are symmetric (you can show this easily!), hence their maxima occur at $z^*=1/2$. Thus, we seek $w/h$ such that
# \begin{align*}
#     \max_{z^*} |v_x^*(0,z^*)-v_{x,P}^*(z^*)| &= |v_x^*(0,1/2) - v_{x,P}^*(1/2)|\\
#     &= \left|\frac{8}{\pi^3}\sum_{n,\text{ odd}}^\infty \frac{1}{n^3} \left\{1 -\frac{1}{\cosh\left(n\pi\delta/2\right)}\right\} \sin\left(n\pi\frac{1}{2}\right) - \left[\frac{1}{2} - \left( \frac{1}{2} \right)^2 \right] \right|\\
#     &= \left| \frac{8}{\pi^3}\sum_{n,\text{ odd}}^\infty \frac{1}{n^3} \left\{1 -\frac{1}{\cosh\left(n\pi\delta/2\right)}\right\} (-1)^{(n-1)/2} - \frac{1}{4} \right| \simeq 0.01.
# \end{align*}
#
# We can evaluate this criterion numerically using SciPy:

# %%
def vel_diff(delta):
    nmax = 100  # 50 terms should be enough
    sum = 0
    for n in range(1, nmax, 2):
        sum = sum + (1/n**3)*(1-1/np.cosh(n*np.pi*delta/2))*(-1)**((n-1)/2)
    diff = np.abs((8/np.pi**3)*sum - 1/4)

    # subtract the RHS of the eq because we'll solve diff - 0.01 = 0 with fsolve
    diff = diff - 0.01
    return diff

initial_guess = 2
print(f'δ ≈ {fsolve(vel_diff, initial_guess)[0]:.4g}')
# Out:
# δ ≈ 2.51

# %% [markdown]
# Thus, $\delta = w/h \approx 2.5$ is "sufficiently wide" to neglect sidewall effects. In other words, if the channel is about $2.5\times$ wider than it is tall, then the effect of the lateral side walls on the centerline velocity is on the order of 1\%, that is, negligible!

# %% [markdown]
# **NOTE**: You should experiment with `nmax` above to ensure that the answer is independent of `nmax`, meaning we took a "sufficient" number of terms in the (technically) infinite series.

# %% [markdown]
# ## References
#
# J. Boussinesq, M&eacute;moire sur l'influence des frottements dans les mouvements r&eacute;guliers des fluides, _J. Math. Pures Appl._ (2) **13** (1868) 377&ndash;424. [Full text](https://www.numdam.org/item/JMPA_1868_2_13__377_0.pdf)
#
# H. Bruus, _Theoretical Microfluidics_, Oxford University Press, 2008. [doi:10.1093/oso/9780199235087.001.0001](https://doi.org/10.1093/oso/9780199235087.001.0001); [Course notes](http://homes.nano.aau.dk/lg/Lab-on-Chip2008_files/HenrikBruus_Microfluidics%20lectures.pdf)
